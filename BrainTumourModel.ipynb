# %%
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Activation
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import plot_model

# %%
pickle_in = open("braintumordata.pickle","rb")
data = pickle.load(pickle_in)

pickle_in = open("braintumorlabels.pickle","rb")
labels = pickle.load(pickle_in)

# %%
data = np.array(data)
labels = np.array(labels)

# %%
data = data/255

# %%
model = Sequential()

model.add(Conv2D(16,3,3, padding = 'same', input_shape= (224,224,3) ))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding = 'same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding = 'same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), padding = 'same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3), padding = 'same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 75, 75, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 75, 75, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 37, 37, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 37, 37, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 37, 37, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 18, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 18, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 18, 18, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 9, 9, 128)         73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 9, 9, 128)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 1,092,132
# Trainable params: 1,091,140
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
filepath="medicalmodelbraintumour-weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
medicalModelHist = model.fit(data, labels, batch_size=64, epochs=100, validation_split=0.3,callbacks=callbacks_list,verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.14490, saving model to medicalmodelbraintumour-weights-improvement-01-0.14.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.14490
#
# Epoch 00003: val_accuracy did not improve from 0.14490
#
# Epoch 00004: val_accuracy did not improve from 0.14490
#
# Epoch 00005: val_accuracy did not improve from 0.14490
#
# Epoch 00006: val_accuracy improved from 0.14490 to 0.15102, saving model to medicalmodelbraintumour-weights-improvement-06-0.15.hdf5
#
# Epoch 00007: val_accuracy improved from 0.15102 to 0.16020, saving model to medicalmodelbraintumour-weights-improvement-07-0.16.hdf5
#
# Epoch 00008: val_accuracy improved from 0.16020 to 0.20102, saving model to medicalmodelbraintumour-weights-improvement-08-0.20.hdf5
#
# Epoch 00009: val_accuracy improved from 0.20102 to 0.44184, saving model to medicalmodelbraintumour-weights-improvement-09-0.44.hdf5
#
# Epoch 00010: val_accuracy improved from 0.44184 to 0.71531, saving model to medicalmodelbraintumour-weights-improvement-10-0.72.hdf5
#
# Epoch 00011: val_accuracy improved from 0.71531 to 0.72041, saving model to medicalmodelbraintumour-weights-improvement-11-0.72.hdf5
#
# Epoch 00012: val_accuracy improved from 0.72041 to 0.81633, saving model to medicalmodelbraintumour-weights-improvement-12-0.82.hdf5
#
# Epoch 00013: val_accuracy improved from 0.81633 to 0.83061, saving model to medicalmodelbraintumour-weights-improvement-13-0.83.hdf5
#
# Epoch 00014: val_accuracy improved from 0.83061 to 0.86939, saving model to medicalmodelbraintumour-weights-improvement-14-0.87.hdf5
#
# Epoch 00015: val_accuracy did not improve from 0.86939
#
# Epoch 00016: val_accuracy did not improve from 0.86939
#
# Epoch 00017: val_accuracy did not improve from 0.86939
#
# Epoch 00018: val_accuracy did not improve from 0.86939
#
# Epoch 00019: val_accuracy did not improve from 0.86939
#
# Epoch 00020: val_accuracy did not improve from 0.86939
#
# Epoch 00021: val_accuracy improved from 0.86939 to 0.90306, saving model to medicalmodelbraintumour-weights-improvement-21-0.90.hdf5
#
# Epoch 00022: val_accuracy did not improve from 0.90306
#
# Epoch 00023: val_accuracy did not improve from 0.90306
#
# Epoch 00024: val_accuracy did not improve from 0.90306
#
# Epoch 00025: val_accuracy did not improve from 0.90306
#
# Epoch 00026: val_accuracy did not improve from 0.90306
#
# Epoch 00027: val_accuracy did not improve from 0.90306
#
# Epoch 00028: val_accuracy did not improve from 0.90306
#
# Epoch 00029: val_accuracy did not improve from 0.90306
#
# Epoch 00030: val_accuracy did not improve from 0.90306
#
# Epoch 00031: val_accuracy improved from 0.90306 to 0.91939, saving model to medicalmodelbraintumour-weights-improvement-31-0.92.hdf5
#
# Epoch 00032: val_accuracy did not improve from 0.91939
#
# Epoch 00033: val_accuracy did not improve from 0.91939
#
# Epoch 00034: val_accuracy did not improve from 0.91939
#
# Epoch 00035: val_accuracy did not improve from 0.91939
#
# Epoch 00036: val_accuracy did not improve from 0.91939
#
# Epoch 00037: val_accuracy did not improve from 0.91939
#
# Epoch 00038: val_accuracy did not improve from 0.91939
#
# Epoch 00039: val_accuracy did not improve from 0.91939
#
# Epoch 00040: val_accuracy did not improve from 0.91939
#
# Epoch 00041: val_accuracy did not improve from 0.91939
#
# Epoch 00042: val_accuracy did not improve from 0.91939
#
# Epoch 00043: val_accuracy did not improve from 0.91939
#
# Epoch 00044: val_accuracy improved from 0.91939 to 0.92143, saving model to medicalmodelbraintumour-weights-improvement-44-0.92.hdf5
#
# Epoch 00045: val_accuracy did not improve from 0.92143
#
# Epoch 00046: val_accuracy did not improve from 0.92143
#
# Epoch 00047: val_accuracy did not improve from 0.92143
#
# Epoch 00048: val_accuracy did not improve from 0.92143
#
# Epoch 00049: val_accuracy did not improve from 0.92143
#
# Epoch 00050: val_accuracy did not improve from 0.92143
#
# Epoch 00051: val_accuracy did not improve from 0.92143
#
# Epoch 00052: val_accuracy did not improve from 0.92143
#
# Epoch 00053: val_accuracy did not improve from 0.92143
#
# Epoch 00054: val_accuracy did not improve from 0.92143
#
# Epoch 00055: val_accuracy did not improve from 0.92143
#
# Epoch 00056: val_accuracy did not improve from 0.92143
#
# Epoch 00057: val_accuracy did not improve from 0.92143
#
# Epoch 00058: val_accuracy did not improve from 0.92143
#
# Epoch 00059: val_accuracy did not improve from 0.92143
#
# Epoch 00060: val_accuracy did not improve from 0.92143
#
# Epoch 00061: val_accuracy improved from 0.92143 to 0.92755, saving model to medicalmodelbraintumour-weights-improvement-61-0.93.hdf5
#
# Epoch 00062: val_accuracy did not improve from 0.92755
#
# Epoch 00063: val_accuracy did not improve from 0.92755
#
# Epoch 00064: val_accuracy did not improve from 0.92755
#
# Epoch 00065: val_accuracy improved from 0.92755 to 0.93265, saving model to medicalmodelbraintumour-weights-improvement-65-0.93.hdf5
#
# Epoch 00066: val_accuracy did not improve from 0.93265
#
# Epoch 00067: val_accuracy did not improve from 0.93265
#
# Epoch 00068: val_accuracy did not improve from 0.93265
#
# Epoch 00069: val_accuracy did not improve from 0.93265
#
# Epoch 00070: val_accuracy did not improve from 0.93265
#
# Epoch 00071: val_accuracy did not improve from 0.93265
#
# Epoch 00072: val_accuracy did not improve from 0.93265
#
# Epoch 00073: val_accuracy did not improve from 0.93265
#
# Epoch 00074: val_accuracy did not improve from 0.93265
#
# Epoch 00075: val_accuracy did not improve from 0.93265
#
# Epoch 00076: val_accuracy did not improve from 0.93265
#
# Epoch 00077: val_accuracy did not improve from 0.93265
#
# Epoch 00078: val_accuracy did not improve from 0.93265
#
# Epoch 00079: val_accuracy did not improve from 0.93265
#
# Epoch 00080: val_accuracy did not improve from 0.93265
#
# Epoch 00081: val_accuracy did not improve from 0.93265
#
# Epoch 00082: val_accuracy did not improve from 0.93265
#
# Epoch 00083: val_accuracy did not improve from 0.93265
#
# Epoch 00084: val_accuracy did not improve from 0.93265
#
# Epoch 00085: val_accuracy did not improve from 0.93265
#
# Epoch 00086: val_accuracy did not improve from 0.93265
#
# Epoch 00087: val_accuracy did not improve from 0.93265
#
# Epoch 00088: val_accuracy did not improve from 0.93265
#
# Epoch 00089: val_accuracy did not improve from 0.93265
#
# Epoch 00090: val_accuracy did not improve from 0.93265
#
# Epoch 00091: val_accuracy did not improve from 0.93265
#
# Epoch 00092: val_accuracy did not improve from 0.93265
#
# Epoch 00093: val_accuracy did not improve from 0.93265
#
# Epoch 00094: val_accuracy did not improve from 0.93265
#
# Epoch 00095: val_accuracy did not improve from 0.93265
#
# Epoch 00096: val_accuracy improved from 0.93265 to 0.93367, saving model to medicalmodelbraintumour-weights-improvement-96-0.93.hdf5
#
# Epoch 00097: val_accuracy did not improve from 0.93367
#
# Epoch 00098: val_accuracy did not improve from 0.93367
#
# Epoch 00099: val_accuracy did not improve from 0.93367
#
# Epoch 00100: val_accuracy did not improve from 0.93367

# %%
pretrained_model = tf.keras.applications.MobileNetV2(input_shape=[224,224,3], include_top=False,weights='imagenet')

# %%
model2 = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4, activation='softmax')
])

# %%
model2.compile(
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
filepath="mobilenetbraintumour-weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 62720)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 250884
# =================================================================
# Total params: 2,508,868
# Trainable params: 2,474,756
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
mobilenetHist = model2.fit(data, labels, batch_size=64, epochs=100, validation_split=0.3,callbacks=callbacks_list,verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.32755, saving model to mobilenetbraintumour-weights-improvement-01-0.33.hdf5
# C:\Users\sulut\anaconda3\envs\gputest\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 00002: val_accuracy improved from 0.32755 to 0.35102, saving model to mobilenetbraintumour-weights-improvement-02-0.35.hdf5
#
# Epoch 00003: val_accuracy improved from 0.35102 to 0.46531, saving model to mobilenetbraintumour-weights-improvement-03-0.47.hdf5
#
# Epoch 00004: val_accuracy did not improve from 0.46531
#
# Epoch 00005: val_accuracy did not improve from 0.46531
#
# Epoch 00006: val_accuracy improved from 0.46531 to 0.52653, saving model to mobilenetbraintumour-weights-improvement-06-0.53.hdf5
#
# Epoch 00007: val_accuracy improved from 0.52653 to 0.54184, saving model to mobilenetbraintumour-weights-improvement-07-0.54.hdf5
#
# Epoch 00008: val_accuracy did not improve from 0.54184
#
# Epoch 00009: val_accuracy did not improve from 0.54184
#
# Epoch 00010: val_accuracy did not improve from 0.54184
#
# Epoch 00011: val_accuracy did not improve from 0.54184
#
# Epoch 00012: val_accuracy did not improve from 0.54184
#
# Epoch 00013: val_accuracy did not improve from 0.54184
#
# Epoch 00014: val_accuracy did not improve from 0.54184
#
# Epoch 00015: val_accuracy did not improve from 0.54184
#
# Epoch 00016: val_accuracy did not improve from 0.54184
#
# Epoch 00017: val_accuracy did not improve from 0.54184
#
# Epoch 00018: val_accuracy did not improve from 0.54184
#
# Epoch 00019: val_accuracy did not improve from 0.54184
#
# Epoch 00020: val_accuracy did not improve from 0.54184
#
# Epoch 00021: val_accuracy did not improve from 0.54184
#
# Epoch 00022: val_accuracy did not improve from 0.54184
#
# Epoch 00023: val_accuracy did not improve from 0.54184
#
# Epoch 00024: val_accuracy did not improve from 0.54184
#
# Epoch 00025: val_accuracy did not improve from 0.54184
#
# Epoch 00026: val_accuracy did not improve from 0.54184
#
# Epoch 00027: val_accuracy did not improve from 0.54184
#
# Epoch 00028: val_accuracy did not improve from 0.54184
#
# Epoch 00029: val_accuracy did not improve from 0.54184
#
# Epoch 00030: val_accuracy did not improve from 0.54184
#
# Epoch 00031: val_accuracy did not improve from 0.54184
#
# Epoch 00032: val_accuracy did not improve from 0.54184
#
# Epoch 00033: val_accuracy did not improve from 0.54184
#
# Epoch 00034: val_accuracy did not improve from 0.54184
#
# Epoch 00035: val_accuracy did not improve from 0.54184
#
# Epoch 00036: val_accuracy did not improve from 0.54184
#
# Epoch 00037: val_accuracy did not improve from 0.54184
#
# Epoch 00038: val_accuracy did not improve from 0.54184
#
# Epoch 00039: val_accuracy did not improve from 0.54184
#
# Epoch 00040: val_accuracy did not improve from 0.54184
#
# Epoch 00041: val_accuracy did not improve from 0.54184
#
# Epoch 00042: val_accuracy did not improve from 0.54184
#
# Epoch 00043: val_accuracy did not improve from 0.54184
#
# Epoch 00044: val_accuracy did not improve from 0.54184
#
# Epoch 00045: val_accuracy did not improve from 0.54184
#
# Epoch 00046: val_accuracy did not improve from 0.54184
#
# Epoch 00047: val_accuracy did not improve from 0.54184
#
# Epoch 00048: val_accuracy did not improve from 0.54184
#
# Epoch 00049: val_accuracy did not improve from 0.54184
#
# Epoch 00050: val_accuracy did not improve from 0.54184
#
# Epoch 00051: val_accuracy did not improve from 0.54184
#
# Epoch 00052: val_accuracy improved from 0.54184 to 0.55204, saving model to mobilenetbraintumour-weights-improvement-52-0.55.hdf5
#
# Epoch 00053: val_accuracy improved from 0.55204 to 0.58469, saving model to mobilenetbraintumour-weights-improvement-53-0.58.hdf5
#
# Epoch 00054: val_accuracy improved from 0.58469 to 0.62245, saving model to mobilenetbraintumour-weights-improvement-54-0.62.hdf5
#
# Epoch 00055: val_accuracy improved from 0.62245 to 0.63673, saving model to mobilenetbraintumour-weights-improvement-55-0.64.hdf5
#
# Epoch 00056: val_accuracy improved from 0.63673 to 0.66020, saving model to mobilenetbraintumour-weights-improvement-56-0.66.hdf5
#
# Epoch 00057: val_accuracy improved from 0.66020 to 0.67041, saving model to mobilenetbraintumour-weights-improvement-57-0.67.hdf5
#
# Epoch 00058: val_accuracy improved from 0.67041 to 0.67653, saving model to mobilenetbraintumour-weights-improvement-58-0.68.hdf5
#
# Epoch 00059: val_accuracy improved from 0.67653 to 0.71224, saving model to mobilenetbraintumour-weights-improvement-59-0.71.hdf5
#
# Epoch 00060: val_accuracy did not improve from 0.71224
#
# Epoch 00061: val_accuracy did not improve from 0.71224
#
# Epoch 00062: val_accuracy did not improve from 0.71224
#
# Epoch 00063: val_accuracy did not improve from 0.71224
#
# Epoch 00064: val_accuracy did not improve from 0.71224
#
# Epoch 00065: val_accuracy did not improve from 0.71224
#
# Epoch 00066: val_accuracy improved from 0.71224 to 0.77347, saving model to mobilenetbraintumour-weights-improvement-66-0.77.hdf5
#
# Epoch 00067: val_accuracy improved from 0.77347 to 0.81531, saving model to mobilenetbraintumour-weights-improvement-67-0.82.hdf5
#
# Epoch 00068: val_accuracy did not improve from 0.81531
#
# Epoch 00069: val_accuracy did not improve from 0.81531
#
# Epoch 00070: val_accuracy did not improve from 0.81531
#
# Epoch 00071: val_accuracy did not improve from 0.81531
#
# Epoch 00072: val_accuracy did not improve from 0.81531
#
# Epoch 00073: val_accuracy did not improve from 0.81531
#
# Epoch 00074: val_accuracy did not improve from 0.81531
#
# Epoch 00075: val_accuracy did not improve from 0.81531
#
# Epoch 00076: val_accuracy did not improve from 0.81531
#
# Epoch 00077: val_accuracy did not improve from 0.81531
#
# Epoch 00078: val_accuracy did not improve from 0.81531
#
# Epoch 00079: val_accuracy did not improve from 0.81531
#
# Epoch 00080: val_accuracy did not improve from 0.81531
#
# Epoch 00081: val_accuracy did not improve from 0.81531
#
# Epoch 00082: val_accuracy did not improve from 0.81531
#
# Epoch 00083: val_accuracy did not improve from 0.81531
#
# Epoch 00084: val_accuracy did not improve from 0.81531
#
# Epoch 00085: val_accuracy did not improve from 0.81531
#
# Epoch 00086: val_accuracy did not improve from 0.81531
#
# Epoch 00087: val_accuracy did not improve from 0.81531
#
# Epoch 00088: val_accuracy did not improve from 0.81531
#
# Epoch 00089: val_accuracy did not improve from 0.81531
#
# Epoch 00090: val_accuracy did not improve from 0.81531
#
# Epoch 00091: val_accuracy did not improve from 0.81531
#
# Epoch 00092: val_accuracy did not improve from 0.81531
#
# Epoch 00093: val_accuracy did not improve from 0.81531
#
# Epoch 00094: val_accuracy did not improve from 0.81531
#
# Epoch 00095: val_accuracy did not improve from 0.81531
#
# Epoch 00096: val_accuracy did not improve from 0.81531
#
# Epoch 00097: val_accuracy did not improve from 0.81531
#
# Epoch 00098: val_accuracy did not improve from 0.81531
#
# Epoch 00099: val_accuracy did not improve from 0.81531
#
# Epoch 00100: val_accuracy did not improve from 0.81531

# %%
print(medicalModelHist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(medicalModelHist.history['accuracy'])
plt.plot(medicalModelHist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(medicalModelHist.history['loss'])
plt.plot(medicalModelHist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(mobilenetHist.history['accuracy'])
plt.plot(mobilenetHist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(mobilenetHist.history['loss'])
plt.plot(mobilenetHist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
