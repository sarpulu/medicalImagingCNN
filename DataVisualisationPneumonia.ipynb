# %%
import pickle
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
import pandas as pd
from matplotlib import pyplot as plt

# %%
pickle_in = open("X.pickle","rb")
data = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
labels = pickle.load(pickle_in)

# %%
data = np.array(data)
labels = np.array(labels)

# %%
print("Images are of shape: {}".format(data.shape))
print("Labels are of shape: {}".format(labels.shape))
# Out:
# Images are of shape: (5216, 256, 256)
# Labels are of shape: (5216,)

# %%
categories = ['NORMAL', 'PNEUMONIA']

# %%
_, label_counts = np.unique(labels, return_counts = True)

# %%
pd.DataFrame({'Labels': label_counts}, index = categories).plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.pie(train_counts,
        explode=(0, 0,) , 
        labels=categories,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()
